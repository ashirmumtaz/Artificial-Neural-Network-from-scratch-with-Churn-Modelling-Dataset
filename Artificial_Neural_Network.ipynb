# %%
# !pip install tensorflow-gpu==2.8.0
# Out:
# Collecting tensorflow-gpu==2.8.0
#   Downloading tensorflow_gpu-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow-gpu==2.8.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow-gpu==2.8.0)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 102.3 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow-gpu==2.8.0)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 49.2 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow-gpu==2.8.0)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.64.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow-gpu==2.8.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.27.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 73.7 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 59.9 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow-gpu
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 2.8.0 which is incompatible.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.8.0 which is incompatible.
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-gpu-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
dataset=pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
x=dataset.iloc[:,3:13]
y=dataset.iloc[:,13]

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
##Feature Engineering

Geography = pd.get_dummies(x['Geography'],drop_first=True)
Gender = pd.get_dummies(x['Gender'],drop_first=True)

# %%
x=x.drop(['Geography','Gender'],axis=1)

# %%
##Concatenate the one hot encoded columns to dataset

x=pd.concat([x,Geography,Gender],axis=1)

# %%
x.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0               1        101348.88    False  False  False
# 1               1        112542.58    False   True  False
# 2               0        113931.57    False  False  False
# 3               0         93826.63    False  False  False
# 4               1         79084.10    False   True  False

# %%
##Spliting the dataset into training and testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
##Lets Create Artificial Neural Network Now
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
##Initialize the ANN
classifier = Sequential() # Initialising the ANN

# %%
##Adding the input Layers
classifier.add(Dense(units=11,activation='relu'))

# %%
##Adding the First Hidden Layer
classifier.add(Dense(units=7,activation='relu'))

# %%
##Adding the second hidden layer
classifier.add(Dense(units=6,activation='relu'))

# %%
##Adding the output layer
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
##Early stoping
import tensorflow as tf
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,

)

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=1000, callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4045 - accuracy: 0.8235 - val_loss: 0.4117 - val_accuracy: 0.8186
# Epoch 2/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3970 - accuracy: 0.8289 - val_loss: 0.4027 - val_accuracy: 0.8232
# Epoch 3/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3870 - accuracy: 0.8386 - val_loss: 0.3967 - val_accuracy: 0.8277
# Epoch 4/1000
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3785 - accuracy: 0.8444 - val_loss: 0.3883 - val_accuracy: 0.8338
# Epoch 5/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3717 - accuracy: 0.8492 - val_loss: 0.3834 - val_accuracy: 0.8376
# Epoch 6/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3651 - accuracy: 0.8522 - val_loss: 0.3771 - val_accuracy: 0.8417
# Epoch 7/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8556 - val_loss: 0.3727 - val_accuracy: 0.8474
# Epoch 8/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3518 - accuracy: 0.8615 - val_loss: 0.3697 - val_accuracy: 0.8516
# Epoch 9/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3469 - accuracy: 0.8623 - val_loss: 0.3691 - val_accuracy: 0.8508
# Epoch 10/1000
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3444 - accuracy: 0.8623 - val_loss: 0.3637 - val_accuracy: 0.8527
# Epoch 11/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3412 - accuracy: 0.8621 - val_loss: 0.3651 - val_accuracy: 0.8546
# Epoch 12/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3384 - accuracy: 0.8625 - val_loss: 0.3639 - val_accuracy: 0.8546
# Epoch 13/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3359 - accuracy: 0.8628 - val_loss: 0.3644 - val_accuracy: 0.8550
# Epoch 14/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3361 - accuracy: 0.8647 - val_loss: 0.3615 - val_accuracy: 0.8561
# Epoch 15/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8643 - val_loss: 0.3630 - val_accuracy: 0.8573
# Epoch 16/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3337 - accuracy: 0.8643 - val_loss: 0.3593 - val_accuracy: 0.8538
# Epoch 17/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3328 - accuracy: 0.8658 - val_loss: 0.3572 - val_accuracy: 0.8550
# Epoch 18/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3318 - accuracy: 0.8673 - val_loss: 0.3603 - val_accuracy: 0.8554
# Epoch 19/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3314 - accuracy: 0.8664 - val_loss: 0.3591 - val_accuracy: 0.8527
# Epoch 20/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8647 - val_loss: 0.3600 - val_accuracy: 0.8527
# Epoch 21/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3301 - accuracy: 0.8636 - val_loss: 0.3581 - val_accuracy: 0.8561
# Epoch 22/1000
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3300 - accuracy: 0.8653 - val_loss: 0.3581 - val_accuracy: 0.8550
# Epoch 23/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3279 - accuracy: 0.8655 - val_loss: 0.3601 - val_accuracy: 0.8538
# Epoch 24/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3282 - accuracy: 0.8658 - val_loss: 0.3633 - val_accuracy: 0.8493
# Epoch 25/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3279 - accuracy: 0.8664 - val_loss: 0.3571 - val_accuracy: 0.8569
# Epoch 26/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3269 - accuracy: 0.8675 - val_loss: 0.3572 - val_accuracy: 0.8573
# Epoch 27/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3266 - accuracy: 0.8660 - val_loss: 0.3619 - val_accuracy: 0.8542
# Epoch 28/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3258 - accuracy: 0.8660 - val_loss: 0.3596 - val_accuracy: 0.8546
# Epoch 29/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3257 - accuracy: 0.8651 - val_loss: 0.3570 - val_accuracy: 0.8565
# Epoch 30/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3254 - accuracy: 0.8664 - val_loss: 0.3588 - val_accuracy: 0.8554
# Epoch 31/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3249 - accuracy: 0.8692 - val_loss: 0.3597 - val_accuracy: 0.8527
# Epoch 32/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.8647 - val_loss: 0.3598 - val_accuracy: 0.8523
# Epoch 33/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3249 - accuracy: 0.8662 - val_loss: 0.3575 - val_accuracy: 0.8542
# Epoch 34/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3239 - accuracy: 0.8683 - val_loss: 0.3574 - val_accuracy: 0.8584
# Epoch 35/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3247 - accuracy: 0.8683 - val_loss: 0.3574 - val_accuracy: 0.8554
# Epoch 36/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3233 - accuracy: 0.8651 - val_loss: 0.3597 - val_accuracy: 0.8554
# Epoch 37/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3235 - accuracy: 0.8681 - val_loss: 0.3593 - val_accuracy: 0.8550
# Epoch 38/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3230 - accuracy: 0.8675 - val_loss: 0.3670 - val_accuracy: 0.8535
# Epoch 39/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3233 - accuracy: 0.8649 - val_loss: 0.3603 - val_accuracy: 0.8561
# Epoch 40/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3225 - accuracy: 0.8683 - val_loss: 0.3601 - val_accuracy: 0.8565
# Epoch 41/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3222 - accuracy: 0.8675 - val_loss: 0.3585 - val_accuracy: 0.8538
# Epoch 42/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3228 - accuracy: 0.8671 - val_loss: 0.3613 - val_accuracy: 0.8550
# Epoch 43/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3218 - accuracy: 0.8658 - val_loss: 0.3599 - val_accuracy: 0.8546
# Epoch 44/1000
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8679 - val_loss: 0.3591 - val_accuracy: 0.8550
# Epoch 45/1000
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3210 - accuracy: 0.8681 - val_loss: 0.3582 - val_accuracy: 0.8561
# Epoch 46/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3219 - accuracy: 0.8683 - val_loss: 0.3584 - val_accuracy: 0.8554
# Epoch 47/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3209 - accuracy: 0.8692 - val_loss: 0.3628 - val_accuracy: 0.8535
# Epoch 48/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3213 - accuracy: 0.8668 - val_loss: 0.3588 - val_accuracy: 0.8535
# Epoch 49/1000
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3201 - accuracy: 0.8692 - val_loss: 0.3594 - val_accuracy: 0.8580
# Epoch 49: early stopping

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
##Predicting the test result
y_pred=classifier.predict(X_test)
y_pred=(y_pred>0.5)

# %%
##Making Confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1485,  110],
#        [ 190,  215]])

# %%
##Calculate the accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.85

# %%
model=model_history.model

# %%
model.save('Churn_Modelling.h5')

# %%
import os
from google.colab import drive
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'myfolder')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive
